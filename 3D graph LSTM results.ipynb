# %%
#jupyter notebook for drawing 3D trajectory

# %%
# load numpy array from npy file
from numpy import load

from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis  
# load array
z = load('z.npy')
x = load('x.npy')
y = load('y.npy')

z_test = load('z_test.npy')
x_test = load('x_test.npy')
y_test = load('y_test.npy')

 
# plotting
ax.plot3D(x_test, y_test, z_test, 'red')
# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot LSTM')
plt.show()
#red for truth 
#green for prediction

# %%
# load numpy array from npy file
from numpy import load

from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis  
# load array
z = load('saved test&predict results\\new_z_pred.npy')[900: 1200]
x = load('saved test&predict results\\new_x_pred.npy')[900: 1200]
y = load('saved test&predict results\\new_y_pred.npy')[900: 1200]

z_test = load('saved test&predict results\\new_z_test.npy')[900: 1200]
x_test = load('saved test&predict results\\new_x_test.npy')[900: 1200]
y_test = load('saved test&predict results\\new_y_test.npy')[900: 1200]

 
# plotting
ax.plot3D(x_test, y_test, z_test, 'red')
# plotting
ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot LSTM trajectory prediction [900: 1200]')
plt.show()
#red for truth 
#green for prediction
